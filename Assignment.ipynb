# %% [markdown]
# # Data Science Assignment

# %% [markdown]
# ## Gautham Krishna K
# ## CB.EN.U4CSE19065

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
countriesCovid = 'https://raw.githubusercontent.com/gkrishnak01/Data-Science-Assignment/main/countries-covid.csv'
covidVaccine = 'https://raw.githubusercontent.com/gkrishnak01/Data-Science-Assignment/main/covidVaccineDataSet.csv'

# %% [markdown]
# ### Reading CSV

# %%
df = pd.read_csv(countriesCovid,na_values = '')
df.head()

# %% [markdown]
# ### Missing Values

# %%
df.fillna(0)
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 108805  2021-07-28     Zimbabwe     103567      71383    3340
# 108806  2021-07-29     Zimbabwe     105656      73394    3421
# 108807  2021-07-30     Zimbabwe     107490      74562    3490
# 108808  2021-07-31     Zimbabwe     108860      75856    3532
# 108809  2021-08-01     Zimbabwe     109546      76665    3583
#
# [108810 rows x 5 columns]

# %%
df.fillna(method='bfill') #Not apt for current dataset
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 108805  2021-07-28     Zimbabwe     103567      71383    3340
# 108806  2021-07-29     Zimbabwe     105656      73394    3421
# 108807  2021-07-30     Zimbabwe     107490      74562    3490
# 108808  2021-07-31     Zimbabwe     108860      75856    3532
# 108809  2021-08-01     Zimbabwe     109546      76665    3583
#
# [108810 rows x 5 columns]

# %%
df.fillna(method='ffill')
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 108805  2021-07-28     Zimbabwe     103567      71383    3340
# 108806  2021-07-29     Zimbabwe     105656      73394    3421
# 108807  2021-07-30     Zimbabwe     107490      74562    3490
# 108808  2021-07-31     Zimbabwe     108860      75856    3532
# 108809  2021-08-01     Zimbabwe     109546      76665    3583
#
# [108810 rows x 5 columns]

# %%
df.dropna()
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 108805  2021-07-28     Zimbabwe     103567      71383    3340
# 108806  2021-07-29     Zimbabwe     105656      73394    3421
# 108807  2021-07-30     Zimbabwe     107490      74562    3490
# 108808  2021-07-31     Zimbabwe     108860      75856    3532
# 108809  2021-08-01     Zimbabwe     109546      76665    3583
#
# [108810 rows x 5 columns]

# %%
df.dropna(axis = 1)
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 108805  2021-07-28     Zimbabwe     103567      71383    3340
# 108806  2021-07-29     Zimbabwe     105656      73394    3421
# 108807  2021-07-30     Zimbabwe     107490      74562    3490
# 108808  2021-07-31     Zimbabwe     108860      75856    3532
# 108809  2021-08-01     Zimbabwe     109546      76665    3583
#
# [108810 rows x 5 columns]

# %%
data = df.fillna(0)
data.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0

# %% [markdown]
# ## iloc

# %%
data.iloc[44639]
# Out:
# Date         2021-08-01
# Country           India
# Confirmed      31655824
# Recovered      30820521
# Deaths           424351
# Name: 44639, dtype: object

# %%
data.iloc[:,4]
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#           ...
# 108805    3340
# 108806    3421
# 108807    3490
# 108808    3532
# 108809    3583
# Name: Deaths, Length: 108810, dtype: int64

# %%
data.iloc[500,4]
# Out:
# 3104

# %%
data.iloc[:,0:3]
# Out:
#               Date      Country  Confirmed
# 0       2020-01-22  Afghanistan          0
# 1       2020-01-23  Afghanistan          0
# 2       2020-01-24  Afghanistan          0
# 3       2020-01-25  Afghanistan          0
# 4       2020-01-26  Afghanistan          0
# ...            ...          ...        ...
# 108805  2021-07-28     Zimbabwe     103567
# 108806  2021-07-29     Zimbabwe     105656
# 108807  2021-07-30     Zimbabwe     107490
# 108808  2021-07-31     Zimbabwe     108860
# 108809  2021-08-01     Zimbabwe     109546
#
# [108810 rows x 3 columns]

# %%
data.iloc[[0,10000,20000,30000,40000,50000,60000,70000,80000,90000,100000],[0,1,2,3,]]
# Out:
#               Date      Country  Confirmed  Recovered
# 0       2020-01-22  Afghanistan          0          0
# 10000   2021-06-19       Belize      13004      12551
# 20000   2021-05-06        Chile    1229248    1166227
# 30000   2021-03-23        Egypt     196709     150924
# 40000   2021-02-07       Guinea      14687      14345
# 50000   2020-12-25   Kazakhstan     196216     170515
# 60000   2020-11-11       Malawi       5955       5366
# 70000   2020-09-28  Netherlands     119509       3755
# 80000   2020-08-15      Romania      69374      32334
# 90000   2020-07-02      Somalia       2944        951
# 100000  2020-05-19      Tunisia       1044        826

# %%
data.iloc[350:450,1:4]
# Out:
#          Country  Confirmed  Recovered
# 350  Afghanistan      53105      42666
# 351  Afghanistan      53207      43291
# 352  Afghanistan      53332      43440
# 353  Afghanistan      53400      43740
# 354  Afghanistan      53489      43948
# ..           ...        ...        ...
# 445  Afghanistan      57160      51989
# 446  Afghanistan      57242      52005
# 447  Afghanistan      57364      52013
# 448  Afghanistan      57492      52022
# 449  Afghanistan      57534      52083
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Set Index

# %%
data.set_index("Country",inplace = True)
data
# Out:
#                    Date  Confirmed  Recovered  Deaths
# Country
# Afghanistan  2020-01-22          0          0       0
# Afghanistan  2020-01-23          0          0       0
# Afghanistan  2020-01-24          0          0       0
# Afghanistan  2020-01-25          0          0       0
# Afghanistan  2020-01-26          0          0       0
# ...                 ...        ...        ...     ...
# Zimbabwe     2021-07-28     103567      71383    3340
# Zimbabwe     2021-07-29     105656      73394    3421
# Zimbabwe     2021-07-30     107490      74562    3490
# Zimbabwe     2021-07-31     108860      75856    3532
# Zimbabwe     2021-08-01     109546      76665    3583
#
# [108810 rows x 4 columns]

# %% [markdown]
# ## LOC

# %%
data.loc['India']
# Out:
#                Date  Confirmed  Recovered  Deaths
# Country
# India    2020-01-22          0          0       0
# India    2020-01-23          0          0       0
# India    2020-01-24          0          0       0
# India    2020-01-25          0          0       0
# India    2020-01-26          0          0       0
# ...             ...        ...        ...     ...
# India    2021-07-28   31528114   30701612  422662
# India    2021-07-29   31572344   30743972  423217
# India    2021-07-30   31613993   30781263  423810
# India    2021-07-31   31655824   30820521  424351
# India    2021-08-01   31655824   30820521  424351
#
# [558 rows x 4 columns]

# %%
data.loc['Germany':'Monaco',['Date','Confirmed']]
# Out:
#                Date  Confirmed
# Country
# Germany  2020-01-22          0
# Germany  2020-01-23          0
# Germany  2020-01-24          0
# Germany  2020-01-25          0
# Germany  2020-01-26          0
# ...             ...        ...
# Monaco   2021-07-28       2833
# Monaco   2021-07-29       2853
# Monaco   2021-07-30       2873
# Monaco   2021-07-31       2889
# Monaco   2021-08-01       2891
#
# [29574 rows x 2 columns]

# %%
data.loc[data['Date'] == '2021-08-01' , 'Confirmed' : 'Deaths']
# Out:
#                     Confirmed  Recovered  Deaths
# Country
# Afghanistan            146523      82586    6677
# Albania                133121     130243    2457
# Algeria                172564     116009    4291
# Andorra                 14678      14210     128
# Angola                  42815      37397    1016
# ...                       ...        ...     ...
# Vietnam                157507      43157    1306
# West Bank and Gaza     316861     311918    3604
# Yemen                    7070       4200    1377
# Zambia                 196293     188106    3406
# Zimbabwe               109546      76665    3583
#
# [195 rows x 3 columns]

# %%
data.loc[((data['Date'] == '2021-08-01') & (data['Confirmed'] > 100000))]
# Out:
#                           Date  Confirmed  Recovered  Deaths
# Country
# Afghanistan         2021-08-01     146523      82586    6677
# Albania             2021-08-01     133121     130243    2457
# Algeria             2021-08-01     172564     116009    4291
# Argentina           2021-08-01    4935847    4581132  105772
# Armenia             2021-08-01     230339     219986    4619
# ...                        ...        ...        ...     ...
# Venezuela           2021-08-01     306673     291556    3607
# Vietnam             2021-08-01     157507      43157    1306
# West Bank and Gaza  2021-08-01     316861     311918    3604
# Zambia              2021-08-01     196293     188106    3406
# Zimbabwe            2021-08-01     109546      76665    3583
#
# [107 rows x 4 columns]

# %%
data.loc[data['Date'].str.startswith('2021')]
# Out:
#                    Date  Confirmed  Recovered  Deaths
# Country
# Afghanistan  2021-01-01      51526      41727    2191
# Afghanistan  2021-01-02      51526      41727    2191
# Afghanistan  2021-01-03      51526      41727    2191
# Afghanistan  2021-01-04      53011      42530    2237
# Afghanistan  2021-01-05      53105      42666    2244
# ...                 ...        ...        ...     ...
# Zimbabwe     2021-07-28     103567      71383    3340
# Zimbabwe     2021-07-29     105656      73394    3421
# Zimbabwe     2021-07-30     107490      74562    3490
# Zimbabwe     2021-07-31     108860      75856    3532
# Zimbabwe     2021-08-01     109546      76665    3583
#
# [41535 rows x 4 columns]

# %% [markdown]
# ## Sorting

# %%
data.sort_values('Recovered',inplace=True, ascending=False)
data
# Out:
#                    Date  Confirmed  Recovered  Deaths
# Country
# India        2021-07-31   31655824   30820521  424351
# India        2021-08-01   31655824   30820521  424351
# India        2021-07-30   31613993   30781263  423810
# India        2021-07-29   31572344   30743972  423217
# India        2021-07-28   31528114   30701612  422662
# ...                 ...        ...        ...     ...
# Comoros      2020-02-24          0          0       0
# Comoros      2020-02-25          0          0       0
# Comoros      2020-02-26          0          0       0
# Comoros      2020-02-27          0          0       0
# Afghanistan  2020-01-22          0          0       0
#
# [108810 rows x 4 columns]

# %% [markdown]
# ## Group By

# %%
data.groupby('Country').sum()
# Out:
#                     Confirmed  Recovered   Deaths
# Country
# Afghanistan          24374384   18042122   978515
# Albania              28254122   22261791   533057
# Algeria              36879660   25317497  1075497
# Andorra               3278923    3042625    40231
# Angola                7247303    5778469   173836
# ...                       ...        ...      ...
# Vietnam               3026352    1113128    23552
# West Bank and Gaza   61884960   56672015   668254
# Yemen                 1404517     759802   324415
# Zambia               23100868   21284847   350613
# Zimbabwe             10397730    8535051   372890
#
# [195 rows x 3 columns]

# %% [markdown]
# ## Plotting

# %%
dataForPlot = pd.read_csv(covidVaccine,na_values='')
dataForPlot.fillna(0, inplace = True)
dataForPlot
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_190240/638956894.py in <module>
# ----> 1 dataForPlot = pd.read_csv(covidVaccine,na_values='')
#       2 dataForPlot.fillna(0, inplace = True)
#       3 dataForPlot
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
firstDose = list(dataForPlot.iloc[:,0])
secondDose = list(dataForPlot.iloc[:,1])
date = range(len(dataForPlot.iloc[:,2]))

# %%
plt.fill_between(date,firstDose,0,color = 'blue',alpha = 0.5,label = 'First Dose')
plt.fill_between(date,secondDose,0,color = 'red',alpha = 0.5, label = 'Second Dose')
plt.legend()
plt.xlabel('Days since start of Covid')
plt.ylabel('Number of Doses Administered e8')
# Out:
# Text(0, 0.5, 'Number of Doses Administered e8')

# %% [markdown]
# ## Data Sources
#
# ### [Countries Covid](https://datahub.io/core/covid-19)
# ### [Covid Vaccine Data](https://api.covid19india.org)
